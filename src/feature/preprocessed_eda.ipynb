# %%
import pymysql
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

matplotlib.rcParams["font.family"] = "AppleGothic"
matplotlib.rcParams["axes.unicode_minus"] = False

# %%
cnx = pymysql.connect(
    user="multi",
    password="*****!",
    host="ec2-15-152-211-160.ap-northeast-3.compute.amazonaws.com",
    database="Data_Mart",
)

query = "SELECT * from Data_Warehouse.preprocessed;"
preprocessed = pd.read_sql(query, cnx)

cnx.close()
# Out:
# /var/folders/_r/qrlg6jnd1l5b_xdkq486q0zr0000gn/T/ipykernel_49839/3705610482.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   preprocessed = pd.read_sql(query, cnx)

# %%
len(preprocessed.columns[4:])
# Out:
# 35

# %%
pd.set_option("display.max_columns", None)
# pd.reset_option('display.max_columns')

preprocessed.describe()
# Out:
#             revenue  cost_of_sales  gross_profit  operating_income  \
# count  3.104000e+03   3.104000e+03  3.104000e+03      3.104000e+03
# mean   3.595552e+12   2.794642e+12  8.009096e+11      3.763874e+11
# std    1.426323e+13   1.055295e+13  4.670911e+12      2.433545e+12
# min    1.747813e+08  -1.417134e+12 -2.964573e+13     -3.265515e+13
# 25%    2.261735e+11   1.430581e+11  3.486732e+10      4.420274e+09
# 50%    6.351794e+11   4.641247e+11  1.033117e+11      2.794221e+10
# 75%    1.899511e+12   1.364390e+12  3.690965e+11      1.215542e+11
# max    3.022314e+14   1.900418e+14  1.131935e+14      5.888667e+13
#
#          net_income          ebit        ebitda  total_equity  total_assets  \
# count  3.104000e+03  3.104000e+03  3.104000e+03  3.104000e+03  3.104000e+03
# mean   1.711726e+11  2.147431e+11  2.588956e+11  2.468624e+12  5.288704e+12
# std    1.778104e+12  2.126078e+12  2.115563e+12  1.338437e+13  2.348794e+13
# min   -2.442911e+13 -3.384362e+13 -2.138221e+13 -7.081860e+11  1.247618e+08
# 25%   -6.634396e+08  6.492615e+08  2.507190e+09  1.546105e+11  3.105483e+11
# 50%    1.526756e+10  2.054284e+10  2.563626e+10  3.686480e+11  7.602369e+11
# 75%    6.942348e+10  9.051659e+10  1.044910e+11  1.103921e+12  2.446173e+12
# max    5.565408e+13  6.115996e+13  6.115996e+13  3.547496e+14  4.484245e+14
#
#        total_liabilities  current_assets  current_liabilities  \
# count       3.104000e+03    3.104000e+03         3.104000e+03
# mean        2.818823e+12    1.949838e+12         1.425631e+12
# std         1.265671e+13    9.549486e+12         5.237951e+12
# min         7.506294e+07    1.659621e+08         1.752545e+08
# 25%         1.120875e+11    1.339949e+11         8.145268e+10
# 50%         3.376177e+11    3.283572e+11         2.361897e+11
# 75%         1.190306e+12    9.742212e+11         7.182821e+11
# max         1.928047e+14    2.184706e+14         8.811713e+13
#
#        non_current_liabilities  short_borrowing  long_borrowing  \
# count             3.104000e+03     3.104000e+03    3.104000e+03
# mean              1.161492e+12     2.805055e+11    4.159166e+11
# std               6.287846e+12     1.135050e+12    3.307818e+12
# min               8.309700e+04     0.000000e+00    0.000000e+00
# 25%               2.089295e+10     8.682100e+08    0.000000e+00
# 50%               7.971852e+10     3.932758e+10    9.992500e+09
# 75%               4.077322e+11     1.461589e+11    8.461798e+10
# max               1.482862e+14     1.745730e+13    9.833412e+13
#
#        cash_and_equivalents  retained_earnings  tangible_assets  \
# count          3.104000e+03       3.104000e+03     3.104000e+03
# mean           3.701589e+11       1.710313e+12     1.801106e+12
# std            1.780137e+12       1.238784e+13     9.614107e+12
# min            4.183128e+06      -4.477062e+12     3.167162e+07
# 25%            1.772571e+10       4.565007e+10     7.253545e+10
# 50%            5.117046e+10       1.903966e+11     2.348657e+11
# 75%            1.593255e+11       5.755624e+11     6.829436e+11
# max            4.968071e+13       3.379464e+14     1.778653e+14
#
#        intangible_assets  accounts_receivable     inventory  accounts_payable  \
# count       3.104000e+03         3.104000e+03  3.104000e+03      3.104000e+03
# mean        2.612110e+11         4.510345e+11  4.282258e+11      3.622611e+11
# std         1.123654e+12         1.773904e+12  1.925114e+12      1.099016e+12
# min         0.000000e+00         0.000000e+00  0.000000e+00      0.000000e+00
# 25%         2.442337e+09         3.484191e+10  2.090564e+10      2.050591e+10
# 50%         1.125521e+10         9.824735e+10  6.967955e+10      6.672042e+10
# 75%         6.349908e+10         2.618549e+11  2.047318e+11      2.141296e+11
# max         2.070350e+13         4.071342e+13  5.218787e+13      1.402489e+13
#
#        outstanding_shares  cash_flow_operating  \
# count        3.104000e+03         3.104000e+03
# mean         9.443312e+07         3.430964e+11
# std          1.255319e+09         2.767140e+12
# min          0.000000e+00        -2.347750e+13
# 25%          1.300000e+07         2.719553e+09
# 50%          2.711247e+07         2.663070e+10
# 75%          5.853996e+07         1.144882e+11
# max          6.099079e+10         6.703186e+13
#
#        selling_general_administrative_expenses  cash_flow_investing  \
# count                             3.104000e+03         3.104000e+03
# mean                              4.207088e+11        -3.251604e+11
# std                               2.584274e+12         2.126764e+12
# min                              -4.399256e+11        -5.362859e+13
# 25%                               2.091450e+10        -1.014161e+11
# 50%                               6.028190e+10        -2.448559e+10
# 75%                               1.831969e+11        -3.032457e+09
# max                               6.881296e+13         1.853258e+12
#
#        cash_flow_financing  long_term_assets      interest           tax  \
# count         3.104000e+03      3.104000e+03  3.104000e+03  3.104000e+03
# mean          4.965360e+10      3.088408e+12  1.074376e+11  6.230442e+10
# std           1.271355e+12      1.374334e+13  6.509985e+11  4.738343e+11
# min          -2.399103e+13      2.558799e+08 -7.323143e+11 -4.695683e+11
# 25%          -2.668124e+10      1.468297e+11  2.170333e+09  7.239116e+08
# 50%          -2.660115e+09      4.071636e+11  8.280524e+09  4.799428e+09
# 75%           2.365660e+10      1.389205e+12  3.420125e+10  2.251176e+10
# max           3.899790e+13      2.299539e+14  1.902769e+13  1.322110e+13
#
#         stock_price  market_capitalization    borrowings  net_liabilities  \
# count  3.065000e+03           3.065000e+03  3.104000e+03     3.104000e+03
# mean   4.426715e+04           2.760645e+12  6.964222e+11     2.448664e+12
# std    1.035658e+05           2.308866e+13  3.820381e+12     1.160145e+13
# min    0.000000e+00           0.000000e+00  0.000000e+00    -1.909728e+12
# 25%    4.450000e+03           1.142460e+11  5.109243e+09     8.097006e+10
# 50%    1.235000e+04           2.751000e+11  6.954828e+10     2.670859e+11
# 75%    4.035000e+04           9.604862e+11  2.791970e+11     9.419243e+11
# max    1.620000e+06           8.918334e+14  9.833412e+13     1.895700e+14
#
#        cash_flow_per_share
# count          3065.000000
# mean           6305.573576
# std           20140.422290
# min         -157950.867612
# 25%              65.206424
# 50%            1092.919135
# 75%            5859.393359
# max          333557.213238

# %% [markdown]
# ### -값 처리
#
# -ve 안되는 변수들: [total_assets, tangible_assets, intangible_assets, cash_and_equivalents, total_liabilities, revenue, cost_of_sales, selling_general_administrative_expenses]
#
# -ve 괜찮은 변수들: [total_equity, operating_income, net_income, cash_flow_operating, cash_flow_investing, cash_flow_financing]

# %%
import pandas as pd

cannot_be_negative = [
    "total_assets",
    "tangible_assets",
    "intangible_assets",
    "cash_and_equivalents",
    "total_liabilities",
    "revenue",
    "cost_of_sales",
    "selling_general_administrative_expenses",
]

negative_columns_dict = {}
negative_values = []

for feature in cannot_be_negative:
    negative_rows = preprocessed.loc[preprocessed[feature] < 0]
    for _, row in negative_rows.iterrows():
        corp_year_key = f"{row['corp']}_{row['year']}"
        negative_columns_dict.setdefault(
            corp_year_key,
            {"corp": row["corp"], "year": row["year"], "negative_columns": []},
        )
        negative_columns_dict[corp_year_key]["negative_columns"].append(feature)

        if row["corp"] == "STX" and any(
            nv["corp"] == "STX" and nv["year"] == row["year"] for nv in negative_values
        ):
            continue

        negative_values.append(row)

for key, value in negative_columns_dict.items():
    print(
        f"Corp: {value['corp']}, Year: {value['year']}, Negative Columns: {', '.join(value['negative_columns'])}"
    )
# Out:
# Corp: STX, Year: 2019, Negative Columns: cost_of_sales, selling_general_administrative_expenses
# Corp: STX, Year: 2020, Negative Columns: cost_of_sales, selling_general_administrative_expenses
# Corp: STX, Year: 2021, Negative Columns: cost_of_sales, selling_general_administrative_expenses
# Corp: STX, Year: 2022, Negative Columns: cost_of_sales, selling_general_administrative_expenses
# Corp: 웅진씽크빅, Year: 2018, Negative Columns: selling_general_administrative_expenses
# Corp: 웅진씽크빅, Year: 2019, Negative Columns: selling_general_administrative_expenses
# Corp: 웅진씽크빅, Year: 2020, Negative Columns: selling_general_administrative_expenses
# Corp: 웅진씽크빅, Year: 2021, Negative Columns: selling_general_administrative_expenses
# Corp: 웅진씽크빅, Year: 2022, Negative Columns: selling_general_administrative_expenses
# Corp: 율촌화학, Year: 2018, Negative Columns: selling_general_administrative_expenses
# Corp: 율촌화학, Year: 2019, Negative Columns: selling_general_administrative_expenses
# Corp: 율촌화학, Year: 2020, Negative Columns: selling_general_administrative_expenses
# Corp: 율촌화학, Year: 2021, Negative Columns: selling_general_administrative_expenses
# Corp: 율촌화학, Year: 2022, Negative Columns: selling_general_administrative_expenses
# Corp: 한화오션, Year: 2018, Negative Columns: selling_general_administrative_expenses

# %%
preprocessed.loc[preprocessed["corp"] == "STX", "cost_of_sales"] = preprocessed.loc[
    preprocessed["corp"] == "STX", "cost_of_sales"
].abs()

preprocessed.loc[
    preprocessed["corp"] == "STX", "selling_general_administrative_expenses"
] = preprocessed.loc[
    preprocessed["corp"] == "STX", "selling_general_administrative_expenses"
].abs()
preprocessed.loc[
    preprocessed["corp"] == "웅진씽크빅", "selling_general_administrative_expenses"
] = preprocessed.loc[
    preprocessed["corp"] == "웅진씽크빅", "selling_general_administrative_expenses"
].abs()
preprocessed.loc[
    preprocessed["corp"] == "율촌화학", "selling_general_administrative_expenses"
] = preprocessed.loc[
    preprocessed["corp"] == "율촌화학", "selling_general_administrative_expenses"
].abs()
preprocessed.loc[
    preprocessed["corp"] == "한화오션", "selling_general_administrative_expenses"
] = preprocessed.loc[
    preprocessed["corp"] == "한화오션", "selling_general_administrative_expenses"
].abs()

# %% [markdown]
# ### 분포 확인

# %%
relevant_features = preprocessed.columns[4:]


def plot_standard_distribution(data, feature, ax):
    sns.kdeplot(data[feature], fill=True, alpha=0.5, color="steelblue", ax=ax)

    ax.set_xlabel(f"{feature}")
    ax.set_ylabel("Density")


fig, axes = plt.subplots(6, 6, figsize=(18, 18))

fig.suptitle("Standard Distribution", fontsize=20)

for i, feature in enumerate(relevant_features):
    ax = axes[i // 6, i % 6]
    plot_standard_distribution(preprocessed, feature, ax)

if len(relevant_features) < 36:
    for i in range(len(relevant_features), 36):
        fig.delaxes(axes[i // 6, i % 6])

sns.despine()

plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %%
correlation_matrix = preprocessed.corr()

# print(correlation_matrix)

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", fmt=".2f", linewidths=2)
plt.title("Correlation Matrix")
plt.show()
# Out:
# /var/folders/_r/qrlg6jnd1l5b_xdkq486q0zr0000gn/T/ipykernel_49839/3799122404.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = preprocessed.corr()

# %%
unique_corp_counts = preprocessed.groupby("sector")["corp"].nunique()
sorted_unique_corp_counts = unique_corp_counts.sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=sorted_unique_corp_counts.index, y=sorted_unique_corp_counts.values)
plt.xlabel("Sector")
plt.ylabel("Unique Corp Count")
plt.title("Number of Unique Corps per Sector")
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = [
    "revenue",
    "net_income",
    "ebitda",
    "operating_income",
    "total_assets",
    "total_equity",
]

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 16))

axes = axes.flatten()

for i, feature in enumerate(features):
    average = preprocessed.groupby("sector")[feature].mean()
    median = preprocessed.groupby("sector")[feature].median()

    sorted_index = average.sort_values(ascending=False).index

    sns.barplot(
        x=sorted_index,
        y=average[sorted_index],
        color="skyblue",
        label="Mean",
        ax=axes[i],
    )

    sns.pointplot(
        x=sorted_index,
        y=median[sorted_index],
        color="red",
        label="Median",
        scale=0.6,
        ax=axes[i],
    )

    axes[i].set_xlabel("Sector")
    axes[i].set_ylabel(feature.capitalize())
    axes[i].set_title(f"Mean and Median {feature.capitalize()} per Sector")
    axes[i].tick_params(axis="x", rotation=90)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
preprocessed.to_csv("final_features.csv", encoding="utf-8-sig", index=False)

# %%
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

username = "multi"
password = "*****!"
hostname = "ec2-15-152-211-160.ap-northeast-3.compute.amazonaws.com"
database_name = "Data_Warehouse"

desired_table_name = "final_features"

cnx = pymysql.connect(user=username, password=password, host=hostname)
cursor = cnx.cursor()

engine = create_engine(
    "mysql+pymysql://{user}:{pw}@{host}/{db}".format(
        user=username, pw=password, db=database_name, host=hostname
    )
)
Session = sessionmaker(bind=engine)
session = Session()

try:
    preprocessed.to_sql(
        desired_table_name, con=engine, if_exists="replace", index=False, chunksize=1000
    )
    session.commit()
except:
    session.rollback()
    raise
finally:
    session.close()

cursor.close()
cnx.close()
